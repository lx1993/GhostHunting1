# %%
import pandas as pd

# %%
client_info_df = pd.read_csv(r'E:\wd_work\unti_cheat\D1_B_0201_0613_0615_B.csv')
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (17,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#######城市变更次数########################

# %%
client_info_df.ACTION_CONTROL.value_counts()
# Out:
# my_home_address        815662
# my_company_name        524858
# my_contact_phone       376697
# my_contact             319647
# my_work_address        137682
# city                    30662
# my_phone                12943
# my_contact_relation      9442
# Name: ACTION_CONTROL, dtype: int64

# %%
client_city_df = client_info_df[client_info_df.ACTION_CONTROL=='city']

# %%
client_city_df.columns
# Out:
# Index(['ACTION_CONTROL', 'ACTION_GROUP', 'ACTION_PAGE', 'ACTION_TEXT',
#        'ACTION_VALUE', 'CLIENT_TIME', 'CREATE_DATE', '中文匹配', 'D3', 'D10', 'F6',
#        'GETTEL(A.MOBILE)', 'ID', 'MACHINE_UUID', 'MAX_MAXOVERDUEDAYS', '记录数',
#        'PUTOUTDATE_TIMES', 'T3%', 'T30#', 'T3#', 'T10#', '[T3->T10]%', 'T10% ',
#        'T20#', 'TEL', 'USER_ID', '日(APPLY_DATE)', '日(MIN_PUTOUTDATE)'],
#       dtype='object')

# %%
city_changed_cnt = client_city_df.drop_duplicates(['USER_ID','ACTION_VALUE'])[['USER_ID','ACTION_VALUE']].groupby('USER_ID').count().reset_index()

# %%
#########详细地址变更次数########################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
# difflib.SequenceMatcher(None,str(addr1),str(addr_list[j])).ratio()

# %%
import re
# newpat=''
# s = '北一中路19号沈阳国际shang？wu'
# news=re.sub(u"[a-z？]",newpat,s)
# def sub_str(text):
#     newpat = ''
#     return re.sub(u"[a-z？]",newpat,text)
client_addr_df.ACTION_VALUE = client_addr_df.ACTION_VALUE.apply(lambda x:re.sub(u"[a-z？]",'',str(x)))
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
client_addr = []
user_idlist = []
client_addr_df['str_len'] = client_addr_df.ACTION_VALUE.str.len()
client_addr_df['str_len1'] =client_addr_df['str_len'].shift(-1).fillna(list(client_addr_df['str_len'])[-1])
client_addr_df['str_len_dif'] = client_addr_df['str_len1']-client_addr_df['str_len']
client_addr_df['str_len_dif1'] =client_addr_df['str_len_dif'].shift(1)
for user_id in set(list(client_addr_df.USER_ID)):
#     print(user_id)
    aa = client_addr_df[client_addr_df.USER_ID==user_id]
    aaaa = aa.iloc[1:-1,:]
    aaa = aaaa[(aaaa.str_len_dif1>=0) & (aaaa.str_len_dif<0)]
    if len(aaa)>=1:
        bb = list(aaa.ACTION_VALUE)
        bb.append(list(aa.iloc[-1:,:].ACTION_VALUE)[-1])
        client_addr.append(bb)
    else:
        client_addr.append(list(aa.iloc[-1:,:].ACTION_VALUE)[-1])
    user_idlist.append(user_id)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
client_addr1 = []
for addr in client_addr:
    aaaaa = []
    if type(addr) != str:       
        for addr1 in addr:
#             print(len(addr1))
            if len(addr1)>5:
                aaaaa.append(addr1)
        client_addr1.append(aaaaa)
    else:
        if len(addr)>5:
            client_addr1.append(addr)
        else:
            client_addr1.append(' ')

# %%
id_list = []
c = 0
for addr in client_addr1:
    
    if type(addr) != str and len(addr)>1:       
        id_list.extend([user_idlist[c],]*len(addr))
        
    elif type(addr) == str or len(addr)==1:
        id_list.append(user_idlist[c])
    c += 1
addr_list = []
for addr in client_addr1:
    if type(addr) != str:       
        addr_list.extend(addr)
        
    elif type(addr) == str :
        addr_list.append(addr)

# %%
ADDR_DF = pd.DataFrame({'USER_ID':id_list,'ADDR':addr_list})

# %%
ADDR_DF['ADDR_LEN'] = ADDR_DF.ADDR.str.len()

# %%
ADDR_DF = ADDR_DF.sort_values(by=['USER_ID','ADDR_LEN'],ascending=False)

# %%
addr_cnt_df = ADDR_DF.groupby('USER_ID').count().reset_index()[['USER_ID','ADDR']].rename(columns={'ADDR':'addr_cnt'})
ADDR_DF1 = pd.merge(ADDR_DF,addr_cnt_df,on='USER_ID',how='left')

# %%
ADDR_DF2 = ADDR_DF1[ADDR_DF1.addr_cnt>1]

# %%
ADDR_DF2
# Out:
#                      ADDR  USER_ID  ADDR_LEN  addr_cnt
# 1                吕岭路1004舍  2793140         8         2
# 2                  吕岭路白糖切  2793140         6         2
# 8          南莲路冶建531号1栋102  2793006        14         4
# 9            南莲路冶建531号1栋Q  2793006        12         4
# 10              南莲路冶建503号  2793006         9         4
# 11               南莲路冶建503  2793006         8         4
# 26          荣乐中路28弄44号501  2792537        13         6
# 27          荣乐中路28弄44号401  2792537        13         6
# 28              荣乐中路28弄45  2792537         9         6
# 29                 荣乐中路38  2792537         6         6
# 30                 荣乐中路38  2792537         6         6
# 31                 荣乐中路27  2792537         6         6
# 32         西丽龙井村西区27栋1001  2792521        14         2
# 33         西丽龙井村西区27栋1001  2792521        14         2
# 36            杏林九天湖路卓毅项目部  2792437        11         2
# 37             杏林九天湖路卓毅建筑  2792437        10         2
# 39         文联路16号金椰大厦702房  2792409        14         9
# 40          文联路16号金椰大厦702  2792409        13         9
# 41          文联路16号金椰大厦702  2792409        13         9
# 42           文联路16号金椰大厦70  2792409        12         9
# 43            文联路16号金椰大厦7  2792409        11         9
# 44            文联路16号金椰大厦7  2792409        11         9
# 45             文联路16号金椰大厦  2792409        10         9
# 46               文联路16号金椰  2792409         8         9
# 47                 文联路16号  2792409         6         9
# 51                新华大街98号  2792257         7         3
# 52                 新华大街98  2792257         6         3
# 53                 名车广场对面  2792257         6         3
# 57           云顶山路501路兴城嘉苑  2792152        12         6
# 58           云顶山路501路兴城嘉苑  2792152        12         6
# ...                   ...      ...       ...       ...
# 42083             阜阳北路82号    42860         7         3
# 42086  祥桥二里大唐世家3期50号3102室    39467        18         5
# 42087     东浦路东浦三里15-2号102    39467        15         5
# 42088            东浦路东浦三里1    39467         8         5
# 42089            工业集中区湖里园    39467         8         5
# 42090             工业集中区湖里    39467         7         5
# 42092        稠江街道戚继光路128号    38629        12         2
# 42093          稠江街道城店路111    38629        10         2
# 42098          东南开发区南溪路5号    35927        10         4
# 42099          东南开发区南溪路5号    35927        10         4
# 42100           东南开发区南溪路6    35927         9         4
# 42101           东南开发区南溪路6    35927         9         4
# 42102        云景路6号平安家园101    35809        12         4
# 42103         云景路6号平安家园10    35809        11         4
# 42104           云景路6号平安家园    35809         9         4
# 42105           星光大道烟墩岭32    35809         9         4
# 42107     莲花池畔小区11栋45楼450    34767        15         2
# 42108        龙江雅苑1栋四单元302    34767        12         2
# 42113       创意英国国际公寓C座916    31177        13         3
# 42114          云投尚苑11栋307    31177        10         3
# 42115              云投尚苑11    31177         6         3
# 42118    邛崃山路68号12栋1单元401    27627        16         2
# 42119           天鹅西湖南路6号3    27627         9         2
# 42122  嘉陵江路兴隆社区57栋三单元406室    26216        18         2
# 42123      嘉陵江路兴隆社区57栋3单元    26216        14         2
# 42125       万科森林公园旭庭B2903    26030        13         3
# 42126         万科森林公园旭庭B25    26030        11         3
# 42127         万科森林公园旭庭B50    26030        11         3
# 42128          解峪乡乐尧村021号    21807        10         2
# 42129              解峪乡乐尧啊    21807         6         2
#
# [20044 rows x 4 columns]

# %%
import difflib
data_box = []
for user_id in set(list(ADDR_DF2.USER_ID)):
    ADDR_DF3 = ADDR_DF2[ADDR_DF2.USER_ID==user_id]
    addr1 = list(ADDR_DF3.ADDR)[0]
    for i in range(1,len(ADDR_DF3)):
        if difflib.SequenceMatcher(None,str(addr1),str( list(ADDR_DF3.ADDR)[i])).ratio()<0.4:
            data_box.append((user_id,addr1,list(ADDR_DF3.ADDR)[i]))

# %%
ADDR_DF3 = pd.DataFrame(data_box,columns=['USER_ID','ADDR1','ADDR2'])

# %%
ADDR_DF3['ADDR_LEN'] = ADDR_DF3.ADDR2.str.len()
ADDR_DF3 = ADDR_DF3.sort_values(by='ADDR_LEN')

# %%
ADDR_DF3
# Out:
#       USER_ID                            ADDR1                     ADDR2  \
# 0     2654270                    大庆路老运管处小区东楼东户                    大庆路看循环
# 614   2669564                        安徽省合肥市肥东县                    南巷138号
# 618   2604037                    旭日路永红一路97号301                    旭日路文头岭
# 623   2178163                     万科金品家园2幢1002                    彩香花苑2撞
# 624   2768037                  白松二路创业花园78栋402室                    白松二路穿越
# 627   2276616            香樟路469号融科东南海ZH2栋3002室                    香樟路468
# 632   2735479                  康桥镇秀沿路3688号昌硕科技                    康桥镇主要路
# 613   2669564                        安徽省合肥市肥东县                    南巷138号
# 633   2735479                  康桥镇秀沿路3688号昌硕科技                    康桥镇主要路
# 636   2538962                     聚宝嘉苑南楼1单元301                    聚宝公园31
# 637   2538962                     聚宝嘉苑南楼1单元301                    聚宝公园31
# 638   2407911                    柏仕公馆十栋二单元1903                    魅力阳光一栋
# 653   2440930                         浑南东路53-5                    荣盛紫提东郡
# 659   2736066                海南省海口市琼山区下坎东93号公寓                    海南省昌江县
# 661   2473988                      宝盖斯威登工业区23号                    新华路321
# 634   2735503                           双凤里29栋                    凤锦路12号
# 612   2472947                晋元庄建西苑中里6号楼4单元201                    晋元庄见习远
# 611   2178021                          曼各村192号                    市二小对你们
# 606   2407298                       安靖镇林湾村校园新居                    安靖镇今晚出
# 561   2471564                      蓝旗街30栋502室内                    蓝旗街三世洞
# 564   1947377                清水河环仓路5号宝清苑四单元409                    清水河环乛乛
# 569   2668352                           埔田镇车田村                    磐东镇肇沟村
# 570   2504542                          鹏程街西苑小区                    民乐街56号
# 573   2406325                     蓉西阳光小区21棟806                    金沙路73号
# 575   2635851               官南大道怡国小区409栋1单元23好                    官南大道长水
# 576   2734304            煤机街跃进路上东城小区4号口一单元804门                    煤机街合作路
# 577   2111731                          白云北路249                    西阳乡秀贝村
# 580   2537722                           百子湾南二路                    十里河文化园
# 581   2373944                   金杨路660弄54号502室                    庄行镇西赵村
# 582   1521978  贵州省黔南布依族苗族自治州都匀市剑江中路培育小区A栋2单元2楼                    贵州省黔南州
# ...       ...                              ...                       ...
# 37    1049578                西三环西湖花园南院6号楼1单元30           中原西路商隐路清华大溪地7号院
# 849   1038141                龙川路星海四季金源1栋2单元905          望湖城望湖北苑18栋四单元607
# 907   2481721               龙华新区建辉路高坳新村278栋605          清泉路联富华庭A座1单元2102
# 192   2724125               二府庄路双龙花园5栋2单元501室内          玄武路宫园中央二号楼2410室内
# 641   2407951     成都市锦江区喜树街680号锦江城市花园一期三栋1901号          成都市锦江区三圣乡幸福梅林幸福路
# 1048  2682545                 ://1..///86821/_          五四路283号天骅大厦783单位
# 161    200292                临平沿山路源山雅阁3幢1单元301          南苑街道君临天下城5幢一单元20
# 473   2437185             大红门中国北京市丰台区石榴庄南街234号          十里河弘善家园211号1809门
# 8     1769802                大学东路98号世贸西城A座3003          鲁班路金水湾小区6栋2单元305
# 151   2493836              丁字湾街道湾田国际木业三期六栋荣宇五金         丁字湾街道双桥小区B五栋四单元五楼
# 1009  2386203              天府新区绿野路508号6栋2单元201         龙华新区民治大道馨园一期7栋301
# 750   2640766      上海市浦东新区崮山路博山路339号菜兄菜弟商贸有限公司         新浦路673弄艾南小区14-402
# 905   1433110         三林镇三舒路181弄东方康达家苑二期19号482         九亭大街100弄兴苑小区8号楼20
# 591   2603623           凤城十一路首创国际城12号楼1单元1903室         太华北路延伸线团结四社浙都商务宾馆
# 1086   225971         陈江街道中京路1号中京电子科技有限公司宿舍楼80        榔梨街道龙华2期43栋305一室一厅
# 429   2304516        福建省泉州市石狮市灵秀创业园二路凯仕达运动有限公司        福建省尤溪县中仙乡华仙村际头尾28号
# 640   2407951     成都市锦江区喜树街680号锦江城市花园一期三栋1901号        成都市锦江区三圣乡幸福梅林幸福路45
# 590   2603623           凤城十一路首创国际城12号楼1单元1903室        太华北路延伸线团结四社浙都商务宾馆3
# 639   2407951     成都市锦江区喜树街680号锦江城市花园一期三栋1901号       成都市锦江区三圣乡幸福梅林幸福路45号
# 241   1480150             东升街道双桂花园三期区10栋2单元10-      中和镇朝阳路盛世嘉苑41栋2单元1402
# 106   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803      成都市武侯区沙堰西二街20号32栋2但愿
# 105   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803      成都市武侯区沙堰西二街20号32栋2但愿
# 50    2491564        湖北省武汉市江岸区台北路北湖夜市北湖下去215号。     野生武汉市江岸区被副业是维护下去还不也是我
# 104   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803    成都市武侯区沙堰西二街20号32栋2单元2漏
# 49    2491564        湖北省武汉市江岸区台北路北湖夜市北湖下去215号。    野生武汉市江岸区被副业是维护下去还不也是我好
# 103   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803    成都市武侯区沙堰西二街20号32栋2单元2漏
# 818     53894           驷马桥仁义路326号青龙鹭苑4栋2单元110    高新西区百草路天河路口106号附26号402
# 102   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803   成都市武侯区沙堰西二街20号32栋2单元2楼4
# 101   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803  成都市武侯区沙堰西二街20号32栋2单元2楼4号
# 100   2787469   成都市温江区光华大道三段燎原路228号珠江御景湾18栋803  成都市武侯区沙堰西二街20号32栋2单元2楼4号
#
#       ADDR_LEN
# 0            6
# 614          6
# 618          6
# 623          6
# 624          6
# 627          6
# 632          6
# 613          6
# 633          6
# 636          6
# 637          6
# 638          6
# 653          6
# 659          6
# 661          6
# 634          6
# 612          6
# 611          6
# 606          6
# 561          6
# 564          6
# 569          6
# 570          6
# 573          6
# 575          6
# 576          6
# 577          6
# 580          6
# 581          6
# 582          6
# ...        ...
# 37          15
# 849         16
# 907         16
# 192         16
# 641         16
# 1048        16
# 161         16
# 473         16
# 8           16
# 151         17
# 1009        17
# 750         17
# 905         17
# 591         17
# 1086        18
# 429         18
# 640         18
# 590         18
# 639         19
# 241         20
# 106         20
# 105         20
# 50          21
# 104         22
# 49          22
# 103         22
# 818         22
# 102         23
# 101         24
# 100         24
#
# [1205 rows x 4 columns]

# %%
import copy
dt = []
for user_id in set(list(ADDR_DF3.USER_ID)):
    addr_df = ADDR_DF3[ADDR_DF3.USER_ID==user_id]
    addr_df = addr_df.sort_values(by='ADDR_LEN',ascending=False)
    aa = list(addr_df.ADDR2)
    aaa = copy.deepcopy(aa)
    print(aaa)
    if addr_df.shape[0]>1:
        for i in range(len(aa)-1):
            for j in range(i+1,len(aa)):
                if difflib.SequenceMatcher(None,str(aa[i]),str(aa[j])).ratio()>0.3:
#                     print(aa[j])
                    if aa[j] in aaa:
                        aaa.remove(aa[j])
    
    dt.append((user_id,aaa))
# Out:
# ['布龙路中百饰大楼一楼驴园', '布龙路中百饰大楼一楼驴', '布龙路中百饰大楼木', '布龙路中百饰大楼木', '布龙路中百饰']
# ['柯桥区大岗镇']
# ['新华路321号', '新华路321']
# ['大坪英利国际B栋3905', '大坪英利国际B董', '大坪英利国际2董']
# ['新洲北村122栋504室', '新洲北村122504', '新洲北村12250']
# ['浙江省哈关系厚实', '浙江省哈关系']
# ['祥和南区万隆公寓']
# ['东部星城西区']
# ['白沙镇中心医院', '白沙镇中心医']
# ['横岗街道华西新村六巷六号10', '横岗街道华西新村六巷']
# ['柯子岭12号']
# ['老一中往前300', '老一中往前30']
# ['长虹大道龙鑫']
# ['家和苑有开商']
# ['湖塘镇亚泰财富中心3029室', '湖塘镇亚泰财富中心3029', '湖塘镇亚泰财']
# ['清水路苑38栋2单元60', '清水路苑38栋']
# ['平洲上潮7:']
# ['黄石市黄石少一']
# ['东三环北路甲49', '东三环北路甲4']
# ['说差南竿败秸唔合６号', '说差南竿败秸唔合６']
# ['北海路999号', '北海路999']
# ['常平镇板石头']
# ['月浦庆安一村101号502']
# ['天府大道北段1']
# ['平西二支路28号201']
# ['大庆路看循环']
# ['新岸苑新岸路']
# ['玉山镇置地廣場']
# ['海泰居小区29号楼三单元401', '海泰居小区28号', '海泰居小区28']
# ['管庄东会西码头']
# ['香榭园林二期']
# ['北京大学第一医院', '北京大学第一医']
# ['十里河弘善家园211号1809门', '十里河弘善园家211号1809', '十里河弘善园家211号18', '十里河弘善家园211号0']
# ['元岭路晓翠园2栋40']
# ['浙江省湖州市无']
# ['官南大道长水机场', '官南大道长水']
# ['珠江路延安社区', '珠江路延安社']
# ['陶吴镇狮子山花苑7高楼601', '陶吴镇狮子山花苑7号楼601', '陶吴镇狮子山花苑7楼601', '陶吴镇狮子山花苑']
# ['福永镇大洋田']
# ['北岗新居小区']
# ['高陵马家湾米家岩']
# ['东兴街道东兴路']
# ['河南省林周师']
# ['玉河东街9号天和园小区', '玉河东街9号天和园小', '玉河东街9\r\n4', '玉河东街9号天']
# ['钢铁路邢钢被生活区', '钢铁路邢钢被生活']
# ['梅川路1295弄', '梅川路1295弄']
# ['江北撒下降出版']
# ['水泥路76号']
# ['下午屯平桥耳翟', '下午屯平桥耳寨', '下午屯平桥洱寨', '下午屯平桥洱']
# ['白沙洲大道6']
# ['玉带中路弓字街仁和小区', '玉带中路弓字街仁和小']
# ['南屏镇广昌村', '南屏镇广昌村']
# ['敢壮大道3·']
# ['南京东路588号', '南京东路588']
# ['体育馆路二一九九', '体育馆路二一九']
# ['铜川路2655弄', '铜川路2655']
# ['赤溪田头长安村39号', '赤溪田头长安村39']
# ['东三旗村龙腾公寓506']
# ['金花镇江安河4组']
# ['南乐路1980号', '南乐路1080号', '南乐路108']
# ['八十三区花样年华乡B栋14G']
# ['革新路凤乛乛']
# ['成都市武侯区沙堰西二街20号32栋2单元2楼4号', '成都市武侯区沙堰西二街20号32栋2单元2楼4号', '成都市武侯区沙堰西二街20号32栋2单元2楼4', '成都市武侯区沙堰西二街20号32栋2单元2漏', '成都市武侯区沙堰西二街20号32栋2单元2漏', '成都市武侯区沙堰西二街20号32栋2但愿', '成都市武侯区沙堰西二街20号32栋2但愿', '成都市武侯区沙堰西二街20号3', '成都市武侯区沙堰西二接', '成都市武侯区沙堰西二接', '成都市武侯区沙眼', '成都市武侯区沙眼']
# ['幸福村中路55', '幸福村中路5']
# ['江公街1号1']
# ['盘欣家园2栋一单元401']
# ['人和镇芳华路']
# ['坂田华为基地']
# ['平远镇迎丰路6']
# ['同和路蜀汉路口']
# ['金富二路39号']
# ['友谊西路街道']
# ['盈丰路以互人']
# ['朔州市古北街农行家', '朔州市古北街农行']
# ['河南岸18号小区']
# ['大朗镇黎贝岭']
# ['福建省厦门市湖里区', '福建省厦门市湖里', '福建省厦门市河']
# ['柳河镇大郑家村大郑家屯', '柳河镇大郑家村大郑家']
# ['北景莲趣一门']
# ['大学东路100号', '大学东路100号', '大学东路100', '大学东路10']
# ['珞瑜东路剑桥春天801']
# ['古荥镇古城村']
# ['城关镇陵南区519号']
# ['煤机街合作路']
# ['上蒲溪瑶族乡温溪村二组', '上蒲溪瑶族乡温溪村二']
# ['万象新天先去']
# ['滆湖东路，周家']
# ['正基香江宇昂']
# ['鹿头镇人民大道2号', '鹿头镇人民大道2']
# ['杨新路80弄7号楼603室']
# ['航城街道莲柄港中国石油航城加']
# ['解放西路61']
# ['张江镇剩下路']
# ['骏鸿实业有限公司']
# ['故县镇安底村秦岭金矿平房家属', '故县镇安底村秦岭金']
# ['海南省海口市龙华区金贸西路']
# ['西阳乡秀贝村']
# ['安全街不委八组', '安全街二委八组', '安全街二委八']
# ['石狮市嘉禄路曾坑']
# ['观山湖区长岭北路十号', '观山湖区长岭北路七号']
# ['十里河文化园']
# ['南州北路一个']
# ['XUEYAN']
# ['甬江街道邬隘村134']
# ['莘南花苑一村一街坊', '莘南花苑一村一街']
# ['水电路1218', '水电路121']
# ['环城路三巷5']
# ['三星路1乛乛', '三星路1乛乛']
# ['观山湖区世纪城社区服务中心', '欢山湖区世纪城社区服务中心', '关山湖区世纪城社区服务中心', '观山湖区世纪城社区服务中', '观山湖区世纪城']
# ['东城区鳌(何', '东城区鳌(何']
# ['龙华新区民治大道馨园一期7栋301']
# ['玄武路宫园中央二号楼2410室内', '玄武路宫园中央二号楼2410', '玄武路宫园中央二号楼']
# ['沥窖长江市场F234', '沥窖长江市场F234', '沥窖长江市场F23', '沥窖长江市场F23', '沥窖长江市场D', '沥窖长江市场D', '沥窖长江市场', '沥窖长江市场']
# ['平沙东街56号', '平沙东街56']
# ['介福乡紫美村']
# ['春都东路月落']
# ['庄行镇西赵村']
# ['桂林路中核浦园396号东方藏', '桂林路中核浦园39']
# ['贵州省黔南州']
# ['樟木头镇龙珠广场']
# ['英姐隔了一天一三号楼', '英姐隔了一天一三号楼', '英姐隔了一天一三']
# ['石湾街道河\u3000', '石湾街道河完', '石湾街道河，', '石湾街道河，', '石湾街道河可']
# ['桐树街安定西路', '桐树街安定西']
# ['杭州易业房产']
# ['沙坪坝区沙洋']
# ['9874364']
# ['四川省凉山州']
# ['鲁班路金水湾小区6栋2单元305', '鲁班路金水湾小区6栋2单位']
# ['盘古乡新丰村新丰刘21号']
# ['石基镇新桥村市莲', '石基镇新桥市莲']
# ['白马寺镇江岭村七组']
# ['犀浦镇学院路']
# ['体育路同辉花园']
# ['玉林七巷9号30']
# ['大兴东路18号']
# ['科创路沙井村123号201']
# ['竟陵办事处大河嘴']
# ['大石街涌口工业一路2号']
# ['新桥镇利是钱']
# ['宝山钢铁股份有限公司', '宝山钢铁股份有限公']
# ['抚州市大公路']
# ['开发区人民I久', '开发区人民工社']
# ['古浪路三我们六']
# ['陈田西约南街一号401']
# ['王卜庄老鸦台']
# ['东建新村11号304']
# ['新圩镇马塘村']
# ['步文镇香榭花都2栋160', '步文镇香榭花都2栋1']
# ['玄武路完了当你']
# ['攀莲镇桥东街29号附996号']
# ['一环路东二段']
# ['北京市朝阳区']
# ['东塔路418号8号楼502', '东塔路418号8号楼502', '东塔路418号8号楼5']
# ['虎门镇茶山北路']
# ['桃都国际城1号2303室']
# ['西园路融城优郡B4栋1002', '西园路融城优郡B4栋1002', '西园路融城优郡B4栋1', '西园路融城优郡B4栋1']
# ['看你是永乐路']
# ['创业路南光正龙村25栋404', '创业路南光正龙村25栋4', '创业路南光正']
# ['兰桂大道1号']
# ['平江区桃花坞中街路148号', '平江区桃花坞中街路148', '平江区桃花坞种结局', '平江区桃花坞中介据', '平江区桃花坞种结', '平江区桃花坞中']
# ['刘山乡红光村3']
# ['黎里镇身体啊']
# ['城门中心小学旁']
# ['朝歌镇朝歌路']
# ['看你695号']
# ['金银湖1号1栋1703']
# ['云投尚苑11栋307', '云投尚苑11']
# ['湖北省宜昌市']
# ['清泉路30号烟台大学', '清泉路30号烟台']
# ['虹星路虹星公寓']
# ['福永和平莱尔德电子材料有限公司', '福永和平莱尔德电子材料有限', '福永和平莱尔德']
# ['王宅保康集团']
# ['联南社区IT']
# ['宾利迷路你想让我']
# ['李桥镇樱花园']
# ['铁溪镇甑子坝村二']
# ['清溪社区董家堰村']
# ['高城村10号60']
# ['福建省尤溪县中仙乡华仙村际头尾28号']
# ["顶效镇团结村'", "顶效镇团结村'"]
# ['圣湖小区十三巷1']
# ['新发地新疆厅']
# ['皓月大路与珠海路']
# ['云枫街道将被劫', '云枫街道将被劫', '云枫街道将被劫', '云枫街道将被']
# ['白纸坊东街1号楼底商', '白纸坊东街1号楼底', '白纸坊东街1']
# ['达狮雄商住区B栋']
# ['大禾乡168号', '大禾乡168']
# ['尧化门尧化门']
# ['新乐苑14号1101室', '新乐苑14号1101']
# ['政务区怀宁市']
# ['十三公里水箱厂，开圣电器旁', '观山湖区西南国际商贸一化', '观山湖区西南国际商贸城', '观山湖区西南国际、', '观山湖区西南国', '观山湖区占儿', '观山湖区占儿']
# ['凤溪大道18乛乛', '凤溪大道18乛', '凤溪大道18号']
# ['相府营6栋402室']
# ['徐泾镇明珠家园2期2', '徐泾镇明珠家']
# ['顺溪镇朱山村']
# ['东浦路东浦三里15-2号102', '工业集中区湖里园', '东浦路东浦三里1', '工业集中区湖里']
# ['滨湖新区滨湖世纪城']
# ['乔司街道和睦桥村15组37号']
# ['福海乡李家地']
# ['盛天华府1505', '盛天华府4505', '盛天华府4502', '盛天华府450']
# ['下洲花园7幢']
# ['商业街21号']
# ['解放南路瑞将']
# ['象山花园二区', '象山花园二区']
# ['运河北路27']
# ['杨桥湖大道阳光时尚商业街1', '杨桥湖大道阳光时尚商']
# ['东坝金马驹桥']
# ['桐乡盛大开元']
# ['东十道三佳购物']
# ['包家花园195号']
# ['秋长镇秋宝路新塘']
# ['江西省南昌市']
# ['首特钢创业公寓2']
# ['会展时代中心3113室', '会展时代中心3113']
# ['天衢路毛孔国际', '天衢路毛孔国']
# ['汽车厂奔驰路同鑫水产对面', '汽车厂奔驰路同鑫水产对']
# ['湖南省东安县白牙市镇烟竹村5', '湖南省东安县白']
# ['福永镇福海二路110号40', '福永镇福海二路']
# ['斜塘金色尚城13栋606']
# ['银海路王凯牛', '银海路王建华']
# ['大良云安路2号']
# ['陈家桥中国银行信用卡']
# ['诺丁山3栋3单元803']
# ['经三路财富广场', '经三路财富广']
# ['宜城街道中性怪那个你', '宜城街道中性怪那']
# ['月华路一二十', '月华路清工一']
# ['四望镇饶文科']
# ['河西街177号']
# ['蒿坪镇黄金村']
# ['徐口镇香山街道', '胥镇香山街道']
# ['南礼士路三天']
# ['北京市望京西路', '北京市望京西']
# ['太华北路延伸线团结四社浙都商务宾馆3', '太华北路延伸线团结四社浙都商务宾馆', '太华北路延伸线团结四社浙都商务', '太华北路延伸线团结']
# ['长乐东路10号楼1单元2604', '长乐东路10号楼1单']
# ['中山门友爱南']
# ['浦江镇我哦你去', '浦江镇我哦你']
# ['湖北省阳新县']
# ['新汶大街好几']
# ['梁湖镇皂李湖村', '梁湖镇皂李湖']
# ['浙江大学舒适社区', '浙江大学玉泉校区', '浙江大学舒适社']
# ['广园西路99号广州客技']
# ['霄云路35号乌巢比萨', '霄云路35号乌巢比']
# ['栖山路苗圃路']
# ['高新西区百草路天河路口106号附26号402']
# ['柏岚子街道59']
# ['龙华新区竹村九']
# ['羊子山路联通营业厅', '羊子山路联通营']
# ['榜头镇泉山村洋尾37号']
# ['天津市大港区']
# ['经海三路29号']
# ['星湖路1RJ']
# ['碧水家园21', '碧水家园21']
# ['联泰香域尚城']
# ['城南路，松鹤社区', '城南路，松鹤社']
# ['朝阳区北双桥村十']
# ['罗锦路258弄38号501室', '罗锦路258弄38号']
# ['大亚湾西区茶山村康盛公寓']
# ['广州致发运输工贸发展有限公司', '广州致发运输工贸发展有限公', '广州致发运输工贸发展']
# ['高沙街道问题的']
# ['南城金丰花园六栋']
# ['兴业街道天波委456']
# ['工行职工去世']
# ['京城国际16栋2006', '京城国际16栋2206', '京城国际16栋200', '京城国际16东大', '京城国际16东大']
# ['学明园商业街']
# ['泗泾镇泗订六']
# ['榔梨街道龙华2期43栋305一室一厅', '榔梨街道龙华2期43栋305室']
# ['唐家沱金色花苑']
# ['罗山镇下埔顶角46号']
# ['海南省文昌市东郊镇', '海南省文昌市东郊', '海南省文昌市']
# ['西关环岛路广宇商务酒店', '西关环岛路广宇商务酒']
# ['太和镇民营科技']
# ['丽江公寓丹霞苑1-2-1402']
# ['铁路小区5号楼201']
# ['海原县好呀想']
# ['西三环 东另路']
# ['19881227', '19881227']
# ['上海街9-12号']
# ['林盛堡镇吴八家子村']
# ['45233019810102', '4523301981010']
# ['黄贝岭设计院小区', '黄贝岭设计院小']
# ['和炯路三彩路']
# ['虹梅南路833号3']
# ['西湖数源软件园', '西湖数源软件']
# ['崇山中路77']
# ['玉山镇台虹科技']
# ['花圃路67426']
# ['江川路299号电气公寓319']
# ['南岸二十三小区魁星阁888号', '南岸二十三小区魁星阁888', '南岸二十三小区魁星阁1', '南岸二十三小']
# ['银滩花园B区1103', '天津市津南区海河教育', '银滩花园B去']
# ['湖北路40号']
# ['辽河二路银座东方', '辽河二路幸运']
# ['西二路银座商城一店', '西二路银座商城一', '西二路银座商']
# ['散花镇工业园区']
# ['朝阳镇朝阳村']
# ['黎家坪镇双塘']
# ['海秀路秀英村402号']
# ['宝安区怡华新']
# ['美丽传奇美容院', '美丽传奇美容']
# ['民权路汉来广场贤良楼3单元61', '民权路汉来广场贤良楼']
# ['中山大道1095号昇晖大厦', '中山大道1095号省会']
# ['谷饶镇仙波工业区', '谷饶镇仙波工业区', '谷饶镇仙波工业']
# ['浙江省杭111111', '浙江省杭11111', '浙江省杭111', '浙江省杭州市讧']
# ['王城大道九都路口', '王城大道九都路']
# ['熊岳镇金星浴池']
# ['银桥镇下阳波完小']
# ['保金路35号']
# ['北二环西段金仕华', '北二环西段金']
# ['南坪东路女子']
# ['复华小区A3-1-.303', '和平街二十二委九十八组', '复华小区A3-1-3']
# ['我，东平村。']
# ['多福路汉正街']
# ['名车广场对面']
# ['一环路南一段']
# ['静宁县人民医院', '静宁县人民医']
# ['阎村绿城足球']
# ['北大南宁巨大']
# ['桂城夏西乛乛']
# ['3874454']
# ['溪南银溪工业区', '溪南银溪工业']
# ['马溪村牌坊5号首']
# ['福建省厦门市']
# ['万达中央华城']
# ['观音桥上岗二路']
# ['你，莫，中哦，这']
# ['平安路送变电公寓二幢204', '平安路送变乛乛']
# ['梁南苑1*2402']
# ['兴三"1)、1', '兴三、",1', '兴三"1)、']
# ['凯迪海运有限公司', '凯迪海运有限']
# ['北京市朝阳区东三环北路远洋']
# ['金柅大道168']
# ['溪城家园7号楼1但愿']
# ['前山万科金域缇香7栋一单元20', '前山万科金域缇香7栋一单']
# ['新浦路673弄艾南小区14-402']
# ['金沙洲金满楼1梯8']
# ['安靖镇今晚出']
# ['胡集镇桥档村']
# ['下庙镇什字村七租组', '下庙镇什字村七组', '下庙镇什字村七']
# ['鹤壁集乡石碑头村3号院', '鹤壁集乡石碑头村3']
# ['永川区二转盘新城', '永川区二转盘新']
# ['云鹤南街24号']
# ['金源南路鑫润广告', '金源南路鑫润广']
# ['万航渡路888号29层', '万航渡路888号29']
# ['葫芦乡李樊村']
# ['龙域西路23号', '龙域西路23']
# ['七经路积漂亮']
# ['创业一路与富通好旺角', '创业一路与富通']
# ['上冈镇镇中路']
# ['万达小区中心', '万达先去洗澡']
# ['泰丰观湖二号楼一单元2302室']
# ['首都机场天衢航空', '首都机场天衢舟']
# ['容桂街道容新乛']
# ['岗厦村东三坊94栋603']
# ['义桥镇金家堰兜60号']
# ['东圃康乐新村']
# ['光明新区乛乛', '光明新区乛乛']
# ['高斯路古桐南路']
# ['星光大道烟墩岭32']
# ['市二小对你们']
# ['中原西路商隐路清华大溪地7号院']
# ['罗家村南乛乛乛']
# ['天鹅西湖南路6号3']
# ['青羊大道99号', '青羊大道99']
# ['晋元庄见习远']
# ['南湖东方莱茵17栋902室']
# ['盘龙区颐所甲']
# ['南巷138号', '南巷138号']
# ['荆竹西路348号', '荆竹西路348']
# ['荣宁道34号']
# ['东风二路南方雅', '东风二路南方']
# ['花牌坊那个药']
# ['旭日路中信水岸城', '旭日路中信水岸', '旭日路文头岭村', '旭日路文头岭']
# ['金城路1088号']
# ['宁南北路如意金水湾', '宁南北路如意金水', '宁南北路如意金']
# ['何山路时代花园7']
# ['东文化47号东6-4-', '东文化47号东']
# ['万柳中路锋尚']
# ['水东建材市场']
# ['通惠南路269']
# ['中兴和园路段（甜蜜时光', '中兴和园路段（']
# ['振兴西路168-2鑫达', '振兴西路168-2号']
# ['深村四街五巷四号一']
# ['舜陵镇五里桥村', '舜陵镇五里桥']
# ['西矿街西宁聚']
# ['五仙桥街驱逐舰你', '五仙桥街驱逐舰', '五仙桥街区庄']
# ['甘柏小区8幢2单元1102']
# ['不会干活叫爸爸']
# ['五马路批发你好']
# ['蒙城北路怔人']
# ['大华三路三十六']
# ['黄阁镇福田七街二']
# ['厚街镇康乐南路87号钻石', '厚街镇康乐南路87', '厚街镇康乐南路', '厚街镇蓝白子']
# ['东方路1953弄13号', '东方路1953弄1']
# ['城南家园中二路2号5栋231', '城南家园中二路2号5栋']
# ['巴城镇正义打工楼']
# ['一一云溪花园', '一一云溪花园', '一一云溪花园']
# ['浮西西宁路南十三巷281', '浮西西宁路南十三巷201', '浮西西宁路南十三巷28']
# ['郭巷镇国泰三村', '郭巷镇国泰三寸']
# ['中枢街道四河村委会王河头42号', '中枢街道四河村委会王河42号', '中枢街道四河村委会呀你个头']
# ['绿地伊顿公馆']
# ['高山路39号']
# ['凤凰玉象路口龙光玖珑', '凤凰玉象路口龙']
# ['闵行区七辛苦毒强烈', '闵行区万科双语', '闵行区七辛苦', '闵行区七辛苦']
# ['龙水北路900弄25', '龙水北路900弄2']
# ['马连道中新佳园16', '马连道中新佳园1']
# ['浮西工业区片']
# ['石景山区政达路6号院4号', '石景山区政达路6号院', '石景山区政法']
# ['海外装饰大厦']
# ['新市大埔乛乛']
# ['中山三路33号']
# ['海洲街道海州洗录完']
# ['湖溪镇夏黄村竹圆路9号', '湖溪镇夏黄村竹圆路9', '湖溪镇夏黄村']
# ['丁头村223号402']
# ['彩香花苑2幢403', '彩香花苑2幢404', '彩香花苑2撞']
# ['天鹅湖路与冬']
# ['丰产路楼阁台村']
# ['浙江省宁波市余姚市', '浙江省宁波市余姚']
# ['三彩路是冤家元，']
# ['惠环镇中星居委']
# ['武威东路821弄27号', '武威东路821弄27', '武威东路821弄']
# ['淮安市青浦区', '淮安市青浦区']
# ['东川公路7568号']
# ['西园路399']
# ['赵家埠534', '赵家埠53号']
# ['3号路口8号大街']
# ['长春新春街道新春', '长春新春接单']
# ['白松二路穿越']
# ['开福区洪山路月', '开福区洪山路']
# ['白中丿一一一﹁一丨田中', '丨﹁一丨一丶']
# ['野生武汉市江岸区被副业是维护下去还不也是我好', '野生武汉市江岸区被副业是维护下去还不也是我', '野生武汉市江岸区被副业是维护下', '野生武汉市江岸区被副业', '野生武汉市江岸区']
# ['机场路近都短']
# ['中山东路福明社']
# ['前铺六里呦吼公寓']
# ['福源小区队员']
# ['清江路5号厂房']
# ['滨濂村蓝湾公寓20', '滨濂村蓝湾公寓']
# ['长庆采三家属区']
# ['电子正街紫薇']
# ['凤起路75号']
# ['白帽镇桥梁村阳排组011号']
# ['平龙西路146号', '平龙西路146']
# ['大旺高新区幸福小区南巷13号']
# ['乐从平步后街一巷']
# ['瓯北镇云广路19号', '瓯北镇云广路19']
# ['湖北省襄阳襄北农场一']
# ['首山路七街十二府5栋90', '首山路七街十']
# ['岗厦村东五坊12号110']
# ['石匠弄17号']
# ['小红门鸿十一']
# ['中南世纪城一期']
# ['万达广场3号楼508']
# ['仙霞西路722号', '仙霞西路722']
# ['桂城芭缇蓝湾1梯101@', '桂城芭缇蓝湾1梯101室']
# ['彩虹大道309号', '彩虹大道30']
# ['南期昌路458弄', '南期昌路45']
# ['大瑶镇李门以']
# ['凤鸣路1号院4号楼407室']
# ['张江镇生一句']
# ["东晓路'''"]
# ['石牌西路8号展望', '石牌西路8号展']
# ['金岭路盛世天下1号楼2单', '金岭路盛世天下1号']
# ['新生尚林花园12503']
# ['东较场街55号', '东较场街55']
# ['阊江路129-9']
# ['高新区益州大道中段', '高新区益州大道中']
# ['典石广场五单元二号楼', '典石广场五单元二号', '典石广场二号楼', '典石广场二号']
# ['高庄镇中峪村']
# ['胜浦镇浪花苑']
# ['香樟路468']
# ['三一员工小区']
# ['洞子口168号']
# ['上海电器科学研究所集团有限公司', '上海电器科学研究所集团有限公司', '上海电器科学研究所集团有限公', '上海电气科学研']
# ['城区二环东路永利幸福广场']
# ['姑孰镇^_^']
# ['万达悲剧戈雅公寓']
# ['钟村镇诜敦村']
# ['罗阳镇桥西七路10座704号', '罗阳镇桥西七路10座704', '罗阳镇桥西七路10座7', '罗阳镇桥西七']
# ['同德街上步村正中巷2号602房']
# ['佛堂镇寄存器奥']
# ['中华北路627']
# ['未央路126号', '未央路126']
# ['口岸街道张马']
# ['机场西乐嘉路62号', '机场西乐嘉路62']
# ['水西门大街建宇大厦', '水西门大街建宇大', '水西门大街建']
# ['锦滨镇雪峰机械厂宿舍', '锦滨镇雪峰机械厂', '锦滨镇雪峰哥机械']
# ['华灯街\r\n\r\n\r\n\r\n']
# ['农业路天民居']
# ['厚街镇百汇电']
# ['点头镇安平街道']
# ['霞林街道坂头小']
# ['南城区雅园新村3栋1414', '南城区雅园新村3栋141', '南城区雅园新村3栋1']
# ['泉水金色阳光家园', '泉水金色阳光家']
# ['等车呢回忆录']
# ['珞瑜东路DL']
# ['陈田村北乛乛']
# ['瑞达汽车销售有限公司', '瑞达汽车销售有限公']
# ['长安镇上角上兴路15', '长安镇上角上兴']
# ['常青街道绿地中心']
# ['宿州市华夏世贸1', '宿州市华夏世']
# ['三都镇城澳城街', '三都镇城澳城']
# ['福建路23号荣耀江南', '福建路23号荣耀江']
# ['沌口经济开发区春晓路6']
# ['山东英才学院北']
# ['452625']
# ['金秀琴。东葛路', '金秀琴东葛路', '青秀区东葛路']
# ['石化路凤凰台南花园15', '石化路凤凰台南花园1']
# ['金牛万达家里']
# ['桥北新区401']
# ['新工小区112', '新工小区11']
# ['海椒市街，东四横街', '海椒市街东四横街']
# ['恒大城5号楼']
# ['康桥镇环桥路1481弄汤巷馨村', '康桥镇主要路', '康桥镇主要路']
# ['石楼镇乐洋洋']
# ['942693']
# ['黄石西路举目无亲']
# ['丁字湾街道双桥小区B五栋四单元五楼']
# ['凤锦路12号']
# ['首南米兰风尚雅苑111', '首南米兰风尚雅']
# ['塘围市场泰港商行13好', '塘围市场13泰港商行']
# ['温泉镇白家疃东']
# ['沙井镇民主大']
# ['西南海三真不']
# ['顾戴2568']
# ['绿城明月江南']
# ['人民路636号', '人民路636']
# ['绿地镜湖世界城', '绿地镜湖世界']
# ['西周镇乌沙山电']
# ['新二路183弄13号10', '新二路183弄13']
# ['渣家小区140号601室', '渣家小区140号6楼']
# ['蛟桥镇金牛小区三区九栋一单元6', '蛟桥镇金牛小区三区九栋']
# ['星河世纪大厦B栋271']
# ['安徽文达信息工程学院', '安徽文达信息工程学', '安徽文达信息']
# ['建设西凤凰镇']
# ['武溪镇大拇指幼儿园']
# ['广西天等，是你刚想动手', '广西天等，是你']
# ['火炬大街168号', '火炬大街168']
# ['深圳路177号', '深圳路177']
# ['东明路383弄6号501', '东明路383弄6号']
# ['聚宝公园31-', '聚宝公园31', '聚宝公园31']
# ['北海路经开过来0', '北海路经开过来']
# ['中和镇朝阳路盛世嘉苑41栋2单元1402']
# ['花桥镇花钱裕花园1幢5']
# ['青屏派出所对面']
# ['白鹤县秀园村']
# ['燕罗街道一人']
# ['魅力阳光一栋']
# ['广东省生意嗯']
# ['兴苑路18号融侨世家']
# ['科兴科学园C3栋401']
# ['翠香街道沿河冬天']
# ['东浮镇后坑福工农山']
# ['成都市锦江区三圣乡幸福梅林幸福路45号', '成都市锦江区三圣乡幸福梅林幸福路45', '成都市锦江区三圣乡幸福梅林幸福路', '成都市锦江区三圣乡幸福梅', '成都市锦江区三圣']
# ['二环路西二段']
# ['塔荣镇人民路26-3']
# ['锦绣花园小区']
# ['九亭大街100弄兴苑小区8号楼20', '九亭大街100弄兴苑小区']
# ['鑫苑路阳光新城']
# ['韩摆渡镇三拐店村中心组', '韩摆渡镇三拐店村中心', '韩摆渡镇三拐店村']
# ['火车站武陵大道']
# ['火炬路56号火炬', '火炬路56426', '火炬路5642', '火炬路56号']
# ['联丰小区11栋2单元']
# ['水北新村三区']
# ['南水镇康宇的']
# ['浑南营城子大街金水湾家园']
# ['包河区蓝鼎星河府9栋1603', '包河区蓝鼎星河度']
# ['新市镇石井镇']
# ['罗宾森源适合']
# ['福永镇和平玻璃围春', '福永镇和平玻璃']
# ['巴庄子路今天', '巴庄子路今天']
# ['榆关镇付庄村029号', '榆关镇付庄村029', '榆关镇付庄村0']
# ['柯桥区笛扬路聚']
# ['站华路7号江南岸小区310']
# ['清泉路联富华庭A座1单元2102', '清泉路联富华庭A座1单元21']
# ['滨江路37号']
# ['许西小区六号楼601']
# ['新安江街道政法路']
# ['南桥镇将孩子']
# ['增槎路江南市场蔬菜二区', '增槎路江南市场蔬菜']
# ['洪塘镇龙西里555', '洪塘镇龙西里']
# ['浒墅关镇甫…']
# ['友谊路141号']
# ['徽州大道与太湖路交口', '徽州大道宝利丰项目部']
# ['五四路319奥体都', '五四路319奥体']
# ['安靖镇方桥村11组', '安靖镇方桥村14', '安靖镇方桥村11']
# ['4208221993', '420822199']
# ['上海市55海淘有限公司', '上海市55海淘有限公', '上海市55海']
# ['怀特嘉园10-1-1283']
# ['吉林省吉林市长春路众泰', '吉林省吉林市长春']
# ['郑开大道与正信路交叉口', '郑开大道与正信路交叉', "郑开大道与正'"]
# ['桃城镇大坪村56号', '桃城镇大坪村56']
# ['时代花园13']
# ['布吉街道罗岗老干一巷10号40', '布吉街道罗岗老干一巷10号', '布吉街道罗岗老干', '布吉街道罗岗']
# ['流沙西园49幢']
# ['南苑街道君临天下城5幢一单元20', '南苑街道君临天下']
# ['北京市丰台区', '北京市丰台区']
# ['山间口大街5号院']
# ['营房村35号']
# ['晋词路后王村东三街18', '晋词路后王村东']
# ['经开区君莱酒店']
# ['广东省惠州南']
# ['正阳街道积福']
# ['善贤路6号V公寓6056', '善贤路6号V宏宇', '善贤路6号V宏', '善贤路6》奥']
# ['西园安居48号楼3']
# ['嘉禾路摩登大厦2520室']
# ['滨海街道善堂街七巷9号', '滨海街道善1']
# ['黄阁翠苑8栋804']
# ['珍铭苑1-3-40']
# ['蓝旗街三世洞']
# ['白石俊源科技']
# ['贵和街25号1-5-1']
# ['天竺镇杨二营村', '天竺镇杨二营']
# ['新津县花源镇柳河五期']
# ['当涂路与临泉路', '当涂路与临泉']
# ['迎宾西路金玉华府']
# ['上三路牛月子']
# ['曹溪镇想才睡']
# ['居佳房地产咨询有限公司']
# ['工业街29-2-4门', '工业街29-2-4', '工业街29-']
# ['西体北路一号', '西体北路一号']
# ['关上街道办事处万兴印象小区', '关上街道办事处万兴印象小']
# ['北街113号']
# ['横沥西城一区群', '横沥西城一区群']
# ['狮岭镇岭南工业区望成路9', '狮岭镇岭南工业区望成路']
# ['柯桥街道办事处', '柯桥街道办事']
# ['五四路283号天骅大厦783单位', '五四路283号天骅大厦783号']
# ['天通苑燕丹村']
# ["三里坡路'''"]
# ['大新路375号', '大新路375好']
# ['六安里31号楼303']
# ['高新区化工路']
# ['徐州市泉山区四级后']
# ['经济技术开发区', '经济技术开发']
# ['官南大道玫魂湾公', '官南大道玫魂湾', '官南大道玫魂滂']
# ['大宁镇大宁村酸870号']
# ['树木岭雅塘村汇城上筑13懂', '树木岭雅塘村汇城上筑']
# ['司门前镇合理村11']
# ['宜城市交警大队']
# ['荣盛紫提东郡']
# ['福永镇下十围']
# ['呈贡大学城云岭路书香大地', '呈贡大学城云岭路书香大', '呈贡大学城云岭路']
# ['芦岭镇邢吴村路东吴组7号', '芦岭镇邢吴村路东五']
# ['福永街道性价']
# ['长安镇星星干完呢']
# ['清水河环乛乛']
# ['凯悦新城56-501', '凯悦新城56-50', '凯悦新城56']
# ['武泰闸武金堤公路马子湖72号', '武泰闸武金堤公路，']
# ['益民巷七幢55号']
# ['同心路28弄2号401室']
# ['繁华大道与祝融路交口', '繁华大道与祝融路交', '繁华大道与祝融']
# ['南昌路8街坊14栋', '南昌路8街坊14']
# ['兴庆路82号']
# ['陈店镇新兴路南八横7、9好', '陈店镇新兴路南八横7、9号']
# ['戚继光大道胜华旅社', '戚继光大道胜华']
# ['热电厂家属楼']
# ['荣城御景4栋']
# ['龙华路34号贵州大厦3十中', '龙华路34号贵州大厦3十中', '龙华路34号贵州大']
# ['海口市美兰区']
# ['银江路137号']
# ['中建信和苑141栋50', '中建信和苑141栋']
# ['天空城五栋三单元1401']
# ['郑州航院东小']
# ['西约街231号']
# ['人民路568号', '人民路568']
# ['灌口镇陈井村五里']
# ['仙女家园3单元5楼']
# ['水木清华1单元1808']
# ['胥口镇中心卫生院', '胥口镇中心卫']
# ['康乐街南二张']
# ['下角铺前街3']
# ['梅河东路龙城华府']
# ['厦门市海沧乛', '厦门市海沧乛', '厦门市海沧乛']
# ['屠甸路836号', '屠甸路836']
# ['平沙村东街十二']
# ['木渎镇灵岩新村8幢508室']
# ['丹竹头地铁站']
# ['八一路73号']
# ['洛溪街道上漖']
# ['滴答主板大楼']
# ['河南省息县杨店']
# ['望湖城望湖北苑18栋四单元607', '望湖城望湖北苑18栋四', '望湖城望湖北苑']
# ['重汽翡翠乛乛']
# ['敦化市锦绣华府', '敦化市锦绣华']
# ['磐东镇肇沟村']
# ['融信澜园7栋3701', '七栋3701']
# ['江川路633弄', '江川路633']
# ['人民路北段117']
# ['东方路华丰路']
# ['阿里山大厦南楼13']
# ['杭州市滨江又', '杭州市滨江道']
# ['丹凤你去后门', '丹凤你去后门']
# ['富滩镇宋溪村109号', '富滩镇宋溪村109']
# ['美加印象小区']
# ['阀门厂家属院']
# ['民乐街56号']
# ['南乐路1980号富士康宿舍']
# ['宝山派出所站中站对面']
# ['金雁大厦171号西苑', '金雁大厦171好', '金雁大厦18']
# ['太平南路114号']
# ['二七路黑泥糊']
# ['天晨家园1栋403室']
# ['阜阳北路82号']
# ['西航港临港路', '西航港临港路']
# ['九亭镇沪亭北路', '九亭镇沪亭北']
# ['兴望路瀚林山水源B段111号', '兴望路瀚林山水源B段111号', '兴望路瀚林山水源B段111', '兴望路瀚林山水源B段', '兴望路瀚林山水源B平', '兴望路瀚林山水源B', '兴望路瀚林山水源已', '兴望路瀚林山水源了', '兴望路瀚林山水源中', '兴望路瀚林山水源', '兴望路瀚林山了', '兴望路瀚林\u3000', '兴望路瀚林山']
# ['湖南省溆浦县解放街八组', '湖南省溆浦解放街八组', '湖南解放街八组']
# ['龙华新区乛乛']
# ['利港镇利港村缪家村', '利港镇利港村缪家']
# ['正源你说呢居']
# ['聚福苑小区2202']
# ['大明湖路272号2-501']
# ['青龙潭路无天门', '青龙潭路与天门']
# ['东山街办迎宾中大道338号', '东山街办迎宾中大道38']
# ['高新三路海佳云顶B座2804']
# ['凤阳东路万福家园']
# ['五联西苑201']
# ['石泉路100弄19号40']
# ['珞璜工业园B区']
# ['松岗松河北路118', '松岗松河北路']
# ['安粮城市广场']
# ['沙头街道上沙塘晏村']
# ['一次性哦大姐']
# ['草场坡翡翠明珠']
# ['两英镇英深路202号伟业数码']
# ['可不，能人蹲给二']
# ['宏迪路92号608室']
# ['下沙经济技术开发区', '下沙经济技术开发', '下沙经济技术']
# ['大洲村沧州街南边路']
# ['莲下镇潜溪工业']
# ['南洲街道南燕路东一街']
# ['金地名轩25']
# ['同集中路中海万锦熙岸9号702', '同集中路中海万锦熙岸9号702', '同集中路中海万锦熙岸9号7', '同集中路中海万锦熙岸9号7']
# ['鸿海大厦1613']
# ['浦建路巴黎春天4楼', '浦建路巴黎春天4']
# ['金沙路73号']
# ['中意二丨ㄥ一丨一一丿ㄥ丶丨', '先锋街道新路安置小区', '中意二丨ㄥ一丨一一']
# ['马府新村23', '马府新村23']
# ['鲁能星城9街区4栋10-2']
# ['海南省昌江县']
# ['湖北祥安智能工程有限公司', '湖北祥安智能工程有限']
# ['祥云路滨湖路', '国瑞城爵士苑']
# ['大柳行头100']
# ['滨江开发区春阳路10号', '滨江开发区春阳路1']
# ['龙美村动漫一']
# ['龙江雅苑1栋四单元302']
# ['和平路西七跇', '和平路西七淌']
# ['东莞长安上沙']
# ['任何^_^^_^^_^', '任何^_^^_^']
# ['江苏省溧阳市昆仑']
# ['中和镇广东路']
# ['朝阳北路各司其职']
# ['能追湾街94号', '能追湾街94']
# ['夏家胡同纪家庙南禾公寓', '夏家胡同纪家庙南禾公']
# ['红旗西路468号金汇大厦', '红旗西路468号金汇大']
# ['长白五街中海明珠', '长白五街中海明']
# ['中上园9好远']
# ['白沙洲一丿丶', '白沙洲一丿丶']

# %%
ADDR_DF4 = pd.DataFrame(dt,columns=['USER_ID','ADDR3'])

# %%
ADDR_DF4
# Out:
#      USER_ID                        ADDR3
# 0    2787328               [布龙路中百饰大楼一楼驴园]
# 1    2541569                     [柯桥区大岗镇]
# 2    2473988                    [新华路321号]
# 3    2568197               [大坪英利国际B栋3905]
# 4    2484228               [新洲北村122栋504室]
# 5     401418                   [浙江省哈关系厚实]
# 6    2637836                   [祥和南区万隆公寓]
# 7    2615315                     [东部星城西区]
# 8    2482197                    [白沙镇中心医院]
# 9    2150421             [横岗街道华西新村六巷六号10]
# 10   2584604                     [柯子岭12号]
# 11   2414621                   [老一中往前300]
# 12   2463776                     [长虹大道龙鑫]
# 13   2744356                     [家和苑有开商]
# 14   1861669             [湖塘镇亚泰财富中心3029室]
# 15   1261605               [清水路苑38栋2单元60]
# 16   2549799                     [平洲上潮7:]
# 17   2697254                    [黄石市黄石少一]
# 18   2535467                   [东三环北路甲49]
# 19   1255468                 [说差南竿败秸唔合６号]
# 20   2777137                    [北海路999号]
# 21   2568247                     [常平镇板石头]
# 22   2738233              [月浦庆安一村101号502]
# 23   2502714                    [天府大道北段1]
# 24   2447420                [平西二支路28号201]
# 25   2654270                     [大庆路看循环]
# 26   2646079                     [新岸苑新岸路]
# 27   1820735                    [玉山镇置地廣場]
# 28   2775105            [海泰居小区29号楼三单元401]
# 29   1742914                    [管庄东会西码头]
# ..       ...                          ...
# 725  1683364                  [大洲村沧州街南边路]
# 726  1879977                    [莲下镇潜溪工业]
# 727  2465706                 [南洲街道南燕路东一街]
# 728   257966                     [金地名轩25]
# 729  2049970            [同集中路中海万锦熙岸9号702]
# 730  2566067                   [鸿海大厦1613]
# 731  2631604                  [浦建路巴黎春天4楼]
# 732  2406325                     [金沙路73号]
# 733  2449333  [中意二丨ㄥ一丨一一丿ㄥ丶丨, 先锋街道新路安置小区]
# 734  2201529                     [马府新村23]
# 735  2693055              [鲁能星城9街区4栋10-2]
# 736  2736066                     [海南省昌江县]
# 737  2021316               [湖北祥安智能工程有限公司]
# 738  2486213             [祥云路滨湖路, 国瑞城爵士苑]
# 739  2195400                    [大柳行头100]
# 740    73674                [滨江开发区春阳路10号]
# 741  2516939                     [龙美村动漫一]
# 742    34767               [龙江雅苑1栋四单元302]
# 743  2228176                     [和平路西七跇]
# 744  2693073                     [东莞长安上沙]
# 745  1908696                [任何^_^^_^^_^]
# 746  2742233                   [江苏省溧阳市昆仑]
# 747  2400223                     [中和镇广东路]
# 748  2731999                   [朝阳北路各司其职]
# 749  2779106                    [能追湾街94号]
# 750  2426850                [夏家胡同纪家庙南禾公寓]
# 751  2584546               [红旗西路468号金汇大厦]
# 752  2723815                   [长白五街中海明珠]
# 753  2527209                     [中上园9好远]
# 754  2510837                     [白沙洲一丿丶]
#
# [755 rows x 2 columns]

# %%
ADDR_DF5 = pd.merge(ADDR_DF3,ADDR_DF4,on='USER_ID',how='left').drop_duplicates(['USER_ID','ADDR1'])

# %%
addr_lists = []
for i in range(len(ADDR_DF5)):
    addr_list  = list(ADDR_DF5.ADDR3)[i]
    addr_list.append(list(ADDR_DF5.ADDR1)[i])
    addr_lists.append([len(addr_list),addr_list])

# %%
ADDR_DF5['addr_changed_cnt'] = [addr[0] for addr in addr_lists]
ADDR_DF5['addr_changed'] = [addr[1] for addr in addr_lists]

# %%
ADDR_DF6 = ADDR_DF5[['USER_ID','addr_changed_cnt','addr_changed']]

# %%
ADDR_DF7 = ADDR_DF1[ADDR_DF1.addr_cnt==1][['USER_ID','addr_cnt','ADDR']]
ADDR_DF7.columns=ADDR_DF6.columns

# %%
ADDR_DF8 = pd.concat([ADDR_DF7,ADDR_DF6],ignore_index=True)

# %%
ADDR_DF8.addr_changed_cnt.value_counts()
# Out:
# 1    22089
# 2      746
# 3        6
# Name: addr_changed_cnt, dtype: int64

# %%
#####################是否精确到详细地址####################################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address'].sort_values(by=['USER_ID','ID']).drop_duplicates('USER_ID',keep='last')

# %%
bool_list = []
for addr in list(client_addr_df.ACTION_VALUE):
    c = 0
    for i in range(10):
        if str(i) in addr:
            c+=1
    if c>0:
        bool_list.append(1)
    else:
        bool_list.append(0)

# %%
client_addr_df['is_addr_accurate'] = bool_list

# %%
is_addr_accurate_df = client_addr_df[['USER_ID','is_addr_accurate']]

# %%
######################模糊详细地址##############################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
client_addr_df1 = client_addr_df[['USER_ID','ACTION_VALUE']]

# %%
client_addr_df1['addr_len'] = client_addr_df1.ACTION_VALUE.str.len()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
client_addr_df1[['ACTION_VALUE','addr_len']]
# Out:
#                ACTION_VALUE  addr_len
# 261174    亦庄经历开发区荣华中路汇丰公寓20      17.0
# 261175      亦庄经历开发区荣华中路汇丰公寓      15.0
# 261176     亦庄经历开发区荣华中路汇丰公寓2      16.0
# 261177     亦庄经历开发区荣华中路汇丰公寓1      16.0
# 261178    亦庄经历开发区荣华中路汇丰公寓11      17.0
# 261179   亦庄经历开发区荣华中路汇丰公寓116      18.0
# 261180              松陵城南花苑4       7.0
# 261181             松陵城南花苑41       8.0
# 261182            松陵城南花苑418       9.0
# 261183           松陵城南花苑418h      10.0
# 261184          松陵城南花苑418ha      11.0
# 261185         松陵城南花苑418hao      12.0
# 261186            松陵城南花苑418       9.0
# 261187           松陵城南花苑418号      10.0
# 261188           松陵城南花苑418号      10.0
# 261189                  河阴镇       3.0
# 261190                河阴镇政府       5.0
# 261191                    河       1.0
# 261192                   河阴       2.0
# 261193                  河阴镇       3.0
# 261194                 河阴镇政       4.0
# 261195                  NaN       NaN
# 261196                  河阴镇       3.0
# 261197               河阴镇南大街       6.0
# 261198            河阴镇南大街河阴镇       9.0
# 261199          河阴镇南大街河阴镇政府      11.0
# 261200                    l       1.0
# 261201                   lo       2.0
# 261202                  lon       3.0
# 261203                 long       4.0
# ...                     ...       ...
# 1752646                 文翔不       3.0
# 1752647                文翔不山       4.0
# 1752648                 文翔还       3.0
# 1752649                文翔不上       4.0
# 1752650                 文翔跻       3.0
# 1752651                 文翔路       3.0
# 1752652                 文翔路       3.0
# 1752653                 文翔路       3.0
# 1752654                 文翔路       3.0
# 1752655                文翔路9       4.0
# 1752656               文翔路92       5.0
# 1752657              文翔路928       6.0
# 1752658             文翔路928=       7.0
# 1752659             文翔路928干       7.0
# 1752660             文翔路928一       7.0
# 1752661             文翔路928弄       7.0
# 1752662             文翔路928弄       7.0
# 1752663             文翔路928王       7.0
# 1752664             文翔路928玉       7.0
# 1752665             文翔路928弄       7.0
# 1752666             文翔路928弄       7.0
# 1752667            文翔路928弄4       8.0
# 1752668           文翔路928弄4、       9.0
# 1752669           文翔路928弄4号       9.0
# 1752670           文翔路928弄4号       9.0
# 1752671           文翔路928弄4号       9.0
# 1752672          文翔路928弄4号1      10.0
# 1752673         文翔路928弄4号11      11.0
# 1752674        文翔路928弄4号110      12.0
# 1752675       文翔路928弄4号1104      13.0
#
# [815662 rows x 2 columns]

# %%
#################是否使用默认输入法######################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
ll = []
userlist = []
for USER_ID in set(list(client_addr_df.USER_ID)):
    ll.append(''.join([str(addr) for addr in list(client_addr_df[client_addr_df.USER_ID==USER_ID].ACTION_VALUE)]))
    userlist.append(USER_ID)

# %%
re.search(u"[a-z]+？+[a-z]",'zz？hz？hozhzhozhonzhongzhong？').group()
# Out:
# 'zz？h'

# %%
is_default_input_list = []
for addrlist in ll:
    try :
        re.search(u"[a-z]+？+[a-z]",addrlist).group()
#         print(addrlist)
        is_default_input_list.append(1)
    except:
        is_default_input_list.append(0)

# %%
is_default_input_df = pd.DataFrame({'USER_ID':userlist,'is_default_input':is_default_input_list})

# %%
##############是否是手写输入#########################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
client_addr_df.head()
# Out:
#          ACTION_CONTROL                          ACTION_GROUP   ACTION_PAGE  \
# 261174  my_home_address  f29b4a00-6e24-44cd-a5cf-eaab0e322572  USER/contact
# 261175  my_home_address  f29b4a00-6e24-44cd-a5cf-eaab0e322572  USER/contact
# 261176  my_home_address  f29b4a00-6e24-44cd-a5cf-eaab0e322572  USER/contact
# 261177  my_home_address  f29b4a00-6e24-44cd-a5cf-eaab0e322572  USER/contact
# 261178  my_home_address  f29b4a00-6e24-44cd-a5cf-eaab0e322572  USER/contact
#
#         ACTION_TEXT       ACTION_VALUE              CLIENT_TIME  \
# 261174          NaN  亦庄经历开发区荣华中路汇丰公寓20  2017/4/3 星期一 上午 9:59:37
# 261175          NaN    亦庄经历开发区荣华中路汇丰公寓  2017/4/3 星期一 上午 9:59:38
# 261176          NaN   亦庄经历开发区荣华中路汇丰公寓2  2017/4/3 星期一 上午 9:59:38
# 261177          NaN   亦庄经历开发区荣华中路汇丰公寓1  2017/4/3 星期一 上午 9:59:40
# 261178          NaN  亦庄经历开发区荣华中路汇丰公寓11  2017/4/3 星期一 上午 9:59:40
#
#                      CREATE_DATE  中文匹配  D3  D10        ...          T30# T3#  \
# 261174  2017/5/3 星期三 上午 10:00:03   NaN   1    1        ...             0   0
# 261175  2017/5/3 星期三 上午 10:00:03   NaN   1    1        ...             0   0
# 261176  2017/5/3 星期三 上午 10:00:03   NaN   1    1        ...             0   0
# 261177  2017/5/3 星期三 上午 10:00:03   NaN   1    1        ...             0   0
# 261178  2017/5/3 星期三 上午 10:00:03   NaN   1    1        ...             0   0
#
#         T10# [T3->T10]%  T10%   T20#                   TEL  USER_ID  \
# 261174     0        NaN  0.00%     0  10391830691816441332  1742371
# 261175     0        NaN  0.00%     0  10391830691816441332  1742371
# 261176     0        NaN  0.00%     0  10391830691816441332  1742371
# 261177     0        NaN  0.00%     0  10391830691816441332  1742371
# 261178     0        NaN  0.00%     0  10391830691816441332  1742371
#
#         日(APPLY_DATE)  日(MIN_PUTOUTDATE)
# 261174  2017/2/10 星期五      2017/2/10 星期五
# 261175  2017/2/10 星期五      2017/2/10 星期五
# 261176  2017/2/10 星期五      2017/2/10 星期五
# 261177  2017/2/10 星期五      2017/2/10 星期五
# 261178  2017/2/10 星期五      2017/2/10 星期五
#
# [5 rows x 28 columns]

# %%
J,一,、,亠,乛

# %%
#############是否含有标点###################################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
ll = []
userlist = []
for USER_ID in set(list(client_addr_df.USER_ID)):
    ll.append(''.join([str(addr) for addr in list(client_addr_df[client_addr_df.USER_ID==USER_ID].ACTION_VALUE)]))
    userlist.append(USER_ID)

# %%
is_obtain_someting_list = []
for l in ll:
    c = 0
    for a in ['(',')','（','）','【','】','[',']','{','}','-','_']:
        if a in l:
            c += 1
    if c == 0:
        is_obtain_someting_list.append(0)
    else:
        is_obtain_someting_list.append(1)

# %%
is_addr_include_punctuation = pd.DataFrame({'USER_ID':userlist,'is_default_input':is_obtain_someting_list})

# %%
###################地址长度最大值#########################################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
client_addr_df['addr_str_len'] = client_addr_df.ACTION_VALUE.str.len()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
max_addr_len_df = client_addr_df[['USER_ID','addr_str_len']].groupby('USER_ID').max().reset_index()

# %%
#################地址最终回落长度######

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
last_addr_len = client_addr_df.sort_values(by=['USER_ID','ID']).drop_duplicates('USER_ID',keep='last')[['USER_ID','ACTION_VALUE']]

# %%
last_addr_len['last_addr_len'] = last_addr_len.ACTION_VALUE.str.len()

# %%
final_fall_addr_len = pd.merge(last_addr_len,max_addr_len_df,on='USER_ID',how='inner')

# %%
final_fall_addr_len['final_fall_addr_len'] = final_fall_addr_len.addr_str_len-final_fall_addr_len.last_addr_len

# %%
final_fall_addr_len_df = final_fall_addr_len[['USER_ID','final_fall_addr_len']]

# %%
####################地址最大回落长度################################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
client_addr_df['addr_str_len'] = client_addr_df.ACTION_VALUE.str.len()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
client_addr_df['addr_str_len_b'] = client_addr_df['addr_str_len'].shift(1)
client_addr_df['addr_str_len_a'] = client_addr_df['addr_str_len'].shift(-1)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
def get_minmum(df):
    aa = []
    if len(df)>=3:
        for i in range(1,len(list(df.addr_str_len))-1):
            if (list(df.addr_str_len)[i]<list(df.addr_str_len)[i-1])&(list(df.addr_str_len)[i]<list(df.addr_str_len)[i+1]):
                aa.append(list(df.addr_str_len)[i])
            else:
                aa.append(9999)
    else:
        aa.append(9999)
    return min(aa)
max_fall_addr_len = client_addr_df.groupby('USER_ID').apply(get_minmum)

# %%
max_fall_addr_len = pd.merge(max_addr_len_df,max_fall_addr_len.reset_index(),on='USER_ID',how='inner')

# %%
max_fall_addr_len.head()
# Out:
#    USER_ID  addr_str_len       0
# 0    21807          10.0     5.0
# 1    26030          13.0     9.0
# 2    26047           7.0     3.0
# 3    26216          21.0     1.0
# 4    26298          23.0  9999.0

# %%
max_fall_addr_len['max_fall_addr_len'] = max_fall_addr_len.addr_str_len-max_fall_addr_len[0]

# %%
max_fall_addr_len.ix[max_fall_addr_len.max_fall_addr_len<0,'max_fall_addr_len'] = -1

# %%
max_fall_addr_len_df = max_fall_addr_len[['USER_ID','max_fall_addr_len']]

# %%
#############城区乡镇####################

# %%
client_addr_df = client_info_df[client_info_df.ACTION_CONTROL=='my_home_address']

# %%
client_addr_df = client_addr_df.sort_values(by=['USER_ID','ID']).drop_duplicates('USER_ID',keep='last')[['USER_ID','ACTION_VALUE']]
